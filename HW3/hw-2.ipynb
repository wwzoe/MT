# %%
# %run nmt_translate.py


_ = predict(s=0, num=10, sample=False)
# Out:
# Japanese English dataset configuration
# vocab size, en=3713, fr=3949
# --------------------------------------------------
# Training progress will be logged in:
# 	model/train_10000sen_1-1layers_100units_ja_en_exp1_NO_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_1-1layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_1-1layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# English predictions, s=0, num=10:
# --------------------------------------------------
# Src | ステーキ は 中位 で 焼 い て くださ い 。
# Ref | i like my steak medium .
# Hyp | i like my steak medium . _EOS
# --------------------------------------------------
# precision | 0.8571
# recall | 1.0000
# --------------------------------------------------
# Src | 彼女 の 美し さ に 関 し て は 、 疑 う 余地 が な い 。
# Ref | there is no doubt as to her beauty .
# Hyp | she is no doubt she her her her . . _EOS
# --------------------------------------------------
# precision | 0.4545
# recall | 0.5556
# --------------------------------------------------
# Src | この 近所 の 家 は どれ も とても よく 似 て い る の で 見分け が つ か な い 。
# Ref | all the houses in this neighborhood look so much alike that i can &apos;t tell them apart .
# Hyp | this are not not not , , , , not &apos;t have a this this . cold . _EOS
# --------------------------------------------------
# precision | 0.1579
# recall | 0.1667
# --------------------------------------------------
# Src | 相撲 を 見 た こと が あ り ま す か 。
# Ref | have you ever watched sumo wrestling ?
# Hyp | have you ever heard ? ? ? _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5714
# --------------------------------------------------
# Src | 彼 は 、 その 川 を 泳 い で 渡 ろ う と し て 失敗 し た 。
# Ref | he failed in his attempt to swim across the river .
# Hyp | he tried to the the the the the door . _EOS
# --------------------------------------------------
# precision | 0.3636
# recall | 0.3636
# --------------------------------------------------
# Src | こちら に 着 い たら すぐ 連絡 し て 下さ い 。
# Ref | get in touch with me as soon as you arrive here .
# Hyp | may as you you you you you you you . . . _EOS
# --------------------------------------------------
# precision | 0.2308
# recall | 0.2500
# --------------------------------------------------
# Src | 昼食 の 後 、 散歩 を する の は どう で す か 。
# Ref | how about going for a walk after lunch ?
# Hyp | how &apos;s going _UNK about your ? ? _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.4444
# --------------------------------------------------
# Src | 彼女 は 彼 を 見 た だけ で も いや だっ た 。
# Ref | the sight of him was hateful to her .
# Hyp | she was to to to to to to his . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3333
# --------------------------------------------------
# Src | うわさ は 四方 八方 に 広が っ た 。
# Ref | the rumor spread far and wide .
# Hyp | the rumor man his to . . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | 老人 は 過去 を 振り返 り がち で あ る 。
# Ref | old people are inclined to look back on the past .
# Hyp | it is running in old yield . . . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.1818
# sentences matching filter = 10

# %%
2 2   4好 6 差

# %%
# %run nmt_translate.py

_ = predict(s=0, num=10, sample=False)
# Out:
# Japanese English dataset configuration
# vocab size, en=3713, fr=3949
# --------------------------------------------------
# Training progress will be logged in:
# 	model/train_10000sen_2-2layers_100units_ja_en_exp1_NO_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_2-2layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_2-2layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# English predictions, s=0, num=10:
# --------------------------------------------------
# Src | ステーキ は 中位 で 焼 い て くださ い 。
# Ref | i like my steak medium .
# Hyp | please like the steak medium . _EOS
# --------------------------------------------------
# precision | 0.5714
# recall | 0.6667
# --------------------------------------------------
# Src | 彼女 の 美し さ に 関 し て は 、 疑 う 余地 が な い 。
# Ref | there is no doubt as to her beauty .
# Hyp | she is no ashamed her her her her . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.4444
# --------------------------------------------------
# Src | この 近所 の 家 は どれ も とても よく 似 て い る の で 見分け が つ か な い 。
# Ref | all the houses in this neighborhood look so much alike that i can &apos;t tell them apart .
# Hyp | i can &apos;t the to to to how the the the . . . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.2778
# --------------------------------------------------
# Src | 相撲 を 見 た こと が あ り ま す か 。
# Ref | have you ever watched sumo wrestling ?
# Hyp | have you have me _UNK _UNK ? _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | 彼 は 、 その 川 を 泳 い で 渡 ろ う と し て 失敗 し た 。
# Ref | he failed in his attempt to swim across the river .
# Hyp | he _UNK his the to the the the . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.4545
# --------------------------------------------------
# Src | こちら に 着 い たら すぐ 連絡 し て 下さ い 。
# Ref | get in touch with me as soon as you arrive here .
# Hyp | please me forget as if as as as as possible . . _EOS
# --------------------------------------------------
# precision | 0.3077
# recall | 0.3333
# --------------------------------------------------
# Src | 昼食 の 後 、 散歩 を する の は どう で す か 。
# Ref | how about going for a walk after lunch ?
# Hyp | how do you you to to your ? ? _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2222
# --------------------------------------------------
# Src | 彼女 は 彼 を 見 た だけ で も いや だっ た 。
# Ref | the sight of him was hateful to her .
# Hyp | she tried that that that was was . . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2222
# --------------------------------------------------
# Src | うわさ は 四方 八方 に 広が っ た 。
# Ref | the rumor spread far and wide .
# Hyp | the rain demanded worked the station . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | 老人 は 過去 を 振り返 り がち で あ る 。
# Ref | old people are inclined to look back on the past .
# Hyp | children are often to to for in the the . . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3636
# sentences matching filter = 10

# %%
3 3  2平 4好

# %%
# %run nmt_translate.py

_ = predict(s=0, num=10, sample=False)
# Out:
# Japanese English dataset configuration
# vocab size, en=3713, fr=3949
# --------------------------------------------------
# Training progress will be logged in:
# 	model/train_10000sen_3-3layers_100units_ja_en_exp1_NO_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_3-3layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_3-3layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# English predictions, s=0, num=10:
# --------------------------------------------------
# Src | ステーキ は 中位 で 焼 い て くださ い 。
# Ref | i like my steak medium .
# Hyp | i like my steak medium . _EOS
# --------------------------------------------------
# precision | 0.8571
# recall | 1.0000
# --------------------------------------------------
# Src | 彼女 の 美し さ に 関 し て は 、 疑 う 余地 が な い 。
# Ref | there is no doubt as to her beauty .
# Hyp | she is &apos;t to to her her her . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.4444
# --------------------------------------------------
# Src | この 近所 の 家 は どれ も とても よく 似 て い る の で 見分け が つ か な い 。
# Ref | all the houses in this neighborhood look so much alike that i can &apos;t tell them apart .
# Hyp | there is to to _UNK _UNK _UNK in in in _UNK _UNK _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.1111
# --------------------------------------------------
# Src | 相撲 を 見 た こと が あ り ま す か 。
# Ref | have you ever watched sumo wrestling ?
# Hyp | can you fix me your ? ? ? _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2857
# --------------------------------------------------
# Src | 彼 は 、 その 川 を 泳 い で 渡 ろ う と し て 失敗 し た 。
# Ref | he failed in his attempt to swim across the river .
# Hyp | he _UNK his effort to his his his . . _EOS
# --------------------------------------------------
# precision | 0.3636
# recall | 0.3636
# --------------------------------------------------
# Src | こちら に 着 い たら すぐ 連絡 し て 下さ い 。
# Ref | get in touch with me as soon as you arrive here .
# Hyp | please me me to you you you you . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.2500
# --------------------------------------------------
# Src | 昼食 の 後 、 散歩 を する の は どう で す か 。
# Ref | how about going for a walk after lunch ?
# Hyp | how you you on the the the the ? ? _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.2222
# --------------------------------------------------
# Src | 彼女 は 彼 を 見 た だけ で も いや だっ た 。
# Ref | the sight of him was hateful to her .
# Hyp | she told her she to her her . . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3333
# --------------------------------------------------
# Src | うわさ は 四方 八方 に 広が っ た 。
# Ref | the rumor spread far and wide .
# Hyp | the brother shook remained the illness . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | 老人 は 過去 を 振り返 り がち で あ る 。
# Ref | old people are inclined to look back on the past .
# Hyp | there is the _UNK the in in films . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.1818
# sentences matching filter = 10

# %%
31 5好

# %%
# %run nmt_translate.py

_ = predict(s=0, num=10, sample=False)
# Out:
# Japanese English dataset configuration
# vocab size, en=3713, fr=3949
# --------------------------------------------------
# Training progress will be logged in:
# 	model/train_10000sen_3-1layers_100units_ja_en_exp1_NO_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_3-1layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_3-1layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# English predictions, s=0, num=10:
# --------------------------------------------------
# Src | ステーキ は 中位 で 焼 い て くださ い 。
# Ref | i like my steak medium .
# Hyp | i like this notebook . . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.5000
# --------------------------------------------------
# Src | 彼女 の 美し さ に 関 し て は 、 疑 う 余地 が な い 。
# Ref | there is no doubt as to her beauty .
# Hyp | there can no no her her her her . . _EOS
# --------------------------------------------------
# precision | 0.3636
# recall | 0.4444
# --------------------------------------------------
# Src | この 近所 の 家 は どれ も とても よく 似 て い る の で 見分け が つ か な い 。
# Ref | all the houses in this neighborhood look so much alike that i can &apos;t tell them apart .
# Hyp | my goes can understand &apos;t understand this this is this this this this this this . . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2222
# --------------------------------------------------
# Src | 相撲 を 見 た こと が あ り ま す か 。
# Ref | have you ever watched sumo wrestling ?
# Hyp | have you ever finished ? ? _EOS
# --------------------------------------------------
# precision | 0.5714
# recall | 0.5714
# --------------------------------------------------
# Src | 彼 は 、 その 川 を 泳 い で 渡 ろ う と し て 失敗 し た 。
# Ref | he failed in his attempt to swim across the river .
# Hyp | he tried to to to to his the the . . _EOS
# --------------------------------------------------
# precision | 0.4167
# recall | 0.4545
# --------------------------------------------------
# Src | こちら に 着 い たら すぐ 連絡 し て 下さ い 。
# Ref | get in touch with me as soon as you arrive here .
# Hyp | please me dad to , , as in my hour . . _EOS
# --------------------------------------------------
# precision | 0.3077
# recall | 0.3333
# --------------------------------------------------
# Src | 昼食 の 後 、 散歩 を する の は どう で す か 。
# Ref | how about going for a walk after lunch ?
# Hyp | what &apos;s you to to ? ? ? ? _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.1111
# --------------------------------------------------
# Src | 彼女 は 彼 を 見 た だけ で も いや だっ た 。
# Ref | the sight of him was hateful to her .
# Hyp | she was not bright her her . . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3333
# --------------------------------------------------
# Src | うわさ は 四方 八方 に 広が っ た 。
# Ref | the rumor spread far and wide .
# Hyp | the drought _UNK the the . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | 老人 は 過去 を 振り返 り がち で あ る 。
# Ref | old people are inclined to look back on the past .
# Hyp | _UNK is _UNK _UNK to his the his . . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.2727
# sentences matching filter = 10

# %%
13 四平四号

# %%
# %run nmt_translate.py

_ = predict(s=0, num=10, sample=False)
# Out:
# Japanese English dataset configuration
# vocab size, en=3713, fr=3949
# --------------------------------------------------
# Training progress will be logged in:
# 	model/train_10000sen_1-3layers_100units_ja_en_exp1_NO_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_1-3layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_1-3layers_100units_ja_en_exp1_NO_ATTN.model
# --------------------------------------------------
# English predictions, s=0, num=10:
# --------------------------------------------------
# Src | ステーキ は 中位 で 焼 い て くださ い 。
# Ref | i like my steak medium .
# Hyp | _UNK _UNK _UNK steak . . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.3333
# --------------------------------------------------
# Src | 彼女 の 美し さ に 関 し て は 、 疑 う 余地 が な い 。
# Ref | there is no doubt as to her beauty .
# Hyp | there is no pleasant of highly her her . . _EOS
# --------------------------------------------------
# precision | 0.4545
# recall | 0.5556
# --------------------------------------------------
# Src | この 近所 の 家 は どれ も とても よく 似 て い る の で 見分け が つ か な い 。
# Ref | all the houses in this neighborhood look so much alike that i can &apos;t tell them apart .
# Hyp | this is is that that in in that staff staff so in in . . . _EOS
# --------------------------------------------------
# precision | 0.2941
# recall | 0.2778
# --------------------------------------------------
# Src | 相撲 を 見 た こと が あ り ま す か 。
# Ref | have you ever watched sumo wrestling ?
# Hyp | have you ever your room ? ? _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5714
# --------------------------------------------------
# Src | 彼 は 、 その 川 を 泳 い で 渡 ろ う と し て 失敗 し た 。
# Ref | he failed in his attempt to swim across the river .
# Hyp | he attempted the the to the swim the the . _EOS
# --------------------------------------------------
# precision | 0.4545
# recall | 0.4545
# --------------------------------------------------
# Src | こちら に 着 い たら すぐ 連絡 し て 下さ い 。
# Ref | get in touch with me as soon as you arrive here .
# Hyp | please drop me yourself you you you you you . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2500
# --------------------------------------------------
# Src | 昼食 の 後 、 散歩 を する の は どう で す か 。
# Ref | how about going for a walk after lunch ?
# Hyp | how many you the your your baseball ? _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2222
# --------------------------------------------------
# Src | 彼女 は 彼 を 見 た だけ で も いや だっ た 。
# Ref | the sight of him was hateful to her .
# Hyp | she ought that to to her her her . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3333
# --------------------------------------------------
# Src | うわさ は 四方 八方 に 広が っ た 。
# Ref | the rumor spread far and wide .
# Hyp | the rumor broke the the students . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | 老人 は 過去 を 振り返 り がち で あ る 。
# Ref | old people are inclined to look back on the past .
# Hyp | the _UNK often famous _UNK a a _UNK . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.1818
# sentences matching filter = 10

# %%
# %run nmt_translate.py

_ = predict(s=0, num=10, sample=False)
# Out:
# Japanese English dataset configuration
# vocab size, en=3713, fr=3949
# --------------------------------------------------
# Training progress will be logged in:
# 	model/train_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.model
# --------------------------------------------------
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.model
# --------------------------------------------------
# English predictions, s=0, num=10:
# --------------------------------------------------
# Src | ステーキ は 中位 で 焼 い て くださ い 。
# Ref | i like my steak medium .
# Hyp | i like steak steak medium . _EOS
# --------------------------------------------------
# precision | 0.7143
# recall | 0.8333
# --------------------------------------------------
# Src | 彼女 の 美し さ に 関 し て は 、 疑 う 余地 が な い 。
# Ref | there is no doubt as to her beauty .
# Hyp | there is no doubt to as beauty beauty her . _EOS
# --------------------------------------------------
# precision | 0.8182
# recall | 1.0000
# --------------------------------------------------
# Src | この 近所 の 家 は どれ も とても よく 似 て い る の で 見分け が つ か な い 。
# Ref | all the houses in this neighborhood look so much alike that i can &apos;t tell them apart .
# Hyp | it _UNK these is just can as as alike it it . . . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.1667
# --------------------------------------------------
# Src | 相撲 を 見 た こと が あ り ま す か 。
# Ref | have you ever watched sumo wrestling ?
# Hyp | have you ever watched _UNK ? _EOS
# --------------------------------------------------
# precision | 0.7143
# recall | 0.7143
# --------------------------------------------------
# Src | 彼 は 、 その 川 を 泳 い で 渡 ろ う と し て 失敗 し た 。
# Ref | he failed in his attempt to swim across the river .
# Hyp | he set to to the across the river . _EOS
# --------------------------------------------------
# precision | 0.6000
# recall | 0.5455
# --------------------------------------------------
# Src | こちら に 着 い たら すぐ 連絡 し て 下さ い 。
# Ref | get in touch with me as soon as you arrive here .
# Hyp | get me with with with with with touch . . _EOS
# --------------------------------------------------
# precision | 0.4545
# recall | 0.4167
# --------------------------------------------------
# Src | 昼食 の 後 、 散歩 を する の は どう で す か 。
# Ref | how about going for a walk after lunch ?
# Hyp | what &apos;s the for after after &apos;s &apos;s ? ? ? _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3333
# --------------------------------------------------
# Src | 彼女 は 彼 を 見 た だけ で も いや だっ た 。
# Ref | the sight of him was hateful to her .
# Hyp | it didn all him at him him _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.1111
# --------------------------------------------------
# Src | うわさ は 四方 八方 に 広が っ た 。
# Ref | the rumor spread far and wide .
# Hyp | the rumor spread wide wide wide _EOS
# --------------------------------------------------
# precision | 0.5714
# recall | 0.5714
# --------------------------------------------------
# Src | 老人 は 過去 を 振り返 り がち で あ る 。
# Ref | old people are inclined to look back on the past .
# Hyp | old people are to to to look look to on . _EOS
# --------------------------------------------------
# precision | 0.5833
# recall | 0.6364
# sentences matching filter = 10

# %%
# %run nmt_translate.py
predict(s=10000, num=6, plot=True)
# Out:
# vocab size, en=3713, fr=3949
# --------------------------------------------------
# Training progress will be logged in:
# 	model/train_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.model
# --------------------------------------------------
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.model
# --------------------------------------------------
# English predictions, s=10000, num=6:
# --------------------------------------------------
# Src | この 路地 は 通り抜け でき ま せ ん 。
# Ref | this is a dead @-@ end alley .
# Hyp | this _UNK can too _UNK . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2500
# --------------------------------------------------
# Src | ええ 、 届 い た の を お 知 らせ する の を 忘れ て しま っ て す み ま せ ん 。
# Ref | yes , sorry , i forgot to acknowledge it .
# Hyp | i don i your to you but but but . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3000
# --------------------------------------------------
# Src | 彼 は ドイツ 生まれ の 人 だ 。
# Ref | he is a german by origin .
# Hyp | he is a in in . . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5714
# --------------------------------------------------
# Src | 我々 は ロビン フッド の 伝説 を 良く 知 っ て い る 。
# Ref | we are familiar with the legend of robin hood .
# Hyp | we know know attention are are all . . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3000
# --------------------------------------------------
# Src | トランク に は 鍵 が かけ られ て い ま す か 。
# Ref | is your trunk locked ?
# Hyp | are you put _UNK _UNK _UNK ? _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.2000
# --------------------------------------------------
# Src | それ は 冗談 の つもり で い っ た だけ だ よ 。
# Ref | i just meant it as a joke .
# Hyp | it &apos;s just that but but just . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3750
# sentences matching filter = 6
# {'cp': [2, 3, 4, 3, 1, 3],
#  't': [8, 10, 7, 10, 5, 8],
#  'tp': [7, 11, 8, 10, 8, 9]}

# %%
_ = predict(s=10000, num=3, plot=True)

# %%
# %run nmt_translate.py

_ = predict(s=10000, num=500, sample=False)
# Out:
# vocab size, en=3713, fr=3949
# --------------------------------------------------
# Training progress will be logged in:
# 	model/train_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.model
# --------------------------------------------------
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_1-1layers_100units_ja_en_exp1_SOFT_ATTN.model
# --------------------------------------------------
# English predictions, s=10000, num=500:
# --------------------------------------------------
# Src | この 路地 は 通り抜け でき ま せ ん 。
# Ref | this is a dead @-@ end alley .
# Hyp | this _UNK can too _UNK . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2500
# --------------------------------------------------
# Src | ええ 、 届 い た の を お 知 らせ する の を 忘れ て しま っ て す み ま せ ん 。
# Ref | yes , sorry , i forgot to acknowledge it .
# Hyp | i don i your to you but but but . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3000
# --------------------------------------------------
# Src | 彼 は ドイツ 生まれ の 人 だ 。
# Ref | he is a german by origin .
# Hyp | he is a in in . . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5714
# --------------------------------------------------
# Src | 我々 は ロビン フッド の 伝説 を 良く 知 っ て い る 。
# Ref | we are familiar with the legend of robin hood .
# Hyp | we know know attention are are all . . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3000
# --------------------------------------------------
# Src | トランク に は 鍵 が かけ られ て い ま す か 。
# Ref | is your trunk locked ?
# Hyp | are you put _UNK _UNK _UNK ? _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.2000
# --------------------------------------------------
# Src | それ は 冗談 の つもり で い っ た だけ だ よ 。
# Ref | i just meant it as a joke .
# Hyp | it &apos;s just that but but just . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3750
# --------------------------------------------------
# Src | その 部屋 は 居心地 の 良 い 感じ が し た 。
# Ref | the room had a nice cozy feel .
# Hyp | the room was talk the . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.3750
# --------------------------------------------------
# Src | パソコン が 使え る の は 彼女 だけ で す 。
# Ref | she alone is able to use the personal computer .
# Hyp | she is well she she she she she . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3000
# --------------------------------------------------
# Src | 彼 ら は 共同 声明 に 同意 し た 。
# Ref | they agreed on a joint statement .
# Hyp | they were agreed on on . . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5714
# --------------------------------------------------
# Src | 彼 は 彼女 を バス に 助け あげ た 。
# Ref | he handed her up into the bus .
# Hyp | he took her for for her . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3750
# --------------------------------------------------
# Src | 彼 に どんな 欠点 が あ る に し て も 、 卑劣 な ところ は な い 。
# Ref | whatever faults he may have , meanness is not one of them .
# Hyp | there is no _UNK his his his his his his . _EOS
# --------------------------------------------------
# precision | 0.1667
# recall | 0.1538
# --------------------------------------------------
# Src | 「 こんな 朝 早く から 開館 し て る ん で す か ？ 」 「 私 は 顔 パス よ 」
# Ref | &quot; will they be open this early in the morning ? &quot; &quot; they &apos;ll let me in on sight . &quot;
# Hyp | &quot; did you a _UNK _UNK _UNK _UNK ? ? _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.0909
# --------------------------------------------------
# Src | 人間 も 極度 に 寒 い 温度 に 対 し て は 、 防御 装置 を 備え て い る 。
# Ref | man , too , has been given protective devices against extreme temperatures .
# Hyp | _UNK are the the cold the the _UNK in _UNK . _EOS
# --------------------------------------------------
# precision | 0.0833
# recall | 0.0769
# --------------------------------------------------
# Src | 私 は タバコ を 吸 う の を やめ た 。
# Ref | i stopped smoking .
# Hyp | i stopped smoking . _EOS
# --------------------------------------------------
# precision | 0.8000
# recall | 1.0000
# --------------------------------------------------
# Src | 彼 は かっと な っ て 私 を 殴 っ た 。
# Ref | he struck me in a passion .
# Hyp | he _UNK me temper temper temper . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | 彼 は ロープ を 引っ張 っ た 。
# Ref | he pulled the rope .
# Hyp | he got his he . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.4000
# --------------------------------------------------
# Src | どう し て あやま っ て 彼 の 許し を こ わ な い ん だ 。
# Ref | why not apologize and ask for his pardon ?
# Hyp | why didn &apos;t succeed him _UNK him . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1111
# --------------------------------------------------
# Src | 私 は 彼 ら は 来る と 思 う 。
# Ref | i suppose they are coming .
# Hyp | i think this . . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3333
# --------------------------------------------------
# Src | 丘 の 上 に 建 っ て い る 家 は とても 古 い 。
# Ref | the house which stands on the hill is very old .
# Hyp | the house is _UNK _UNK hill hill hill _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.3636
# --------------------------------------------------
# Src | 私 は 早 く 着 き すぎ た 。
# Ref | i arrived there too early .
# Hyp | i came so up . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3333
# --------------------------------------------------
# Src | 私 は 彼 の 親切 に こたえ た い 。
# Ref | i would like to repay him for his kindness .
# Hyp | i want his to his . _EOS
# --------------------------------------------------
# precision | 0.5714
# recall | 0.4000
# --------------------------------------------------
# Src | 屋根 は 強風 に 飛ば さ れ た 。
# Ref | the roof was torn off by the gale .
# Hyp | the _UNK was was _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3333
# --------------------------------------------------
# Src | 霧 の 中 から 突然 船 が 現れ た 。
# Ref | a boat suddenly appeared out of the mist .
# Hyp | a the _UNK at all the the . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3333
# --------------------------------------------------
# Src | 車 が 衝突 し た とき シート ベルト を し て い た ら 、 彼 は 今 で も 生き て い る だ ろ う 。
# Ref | he would still be alive if he had been wearing his seat belt when the car crashed .
# Hyp | i will write , when when when , , but . _EOS
# --------------------------------------------------
# precision | 0.1667
# recall | 0.1111
# --------------------------------------------------
# Src | あなた が 結婚 し 子供 を 持 っ た ら 、 言葉 より 実践 と い う こと を 悟 る で しょ う 。
# Ref | when you get married and have kids , you &apos;ll realize that actions speak louder than words .
# Hyp | i will make a a _UNK children children children children children children . _EOS
# --------------------------------------------------
# precision | 0.0714
# recall | 0.0556
# --------------------------------------------------
# Src | それ は 遺憾 な ところ が 多 い 。
# Ref | it leaves nothing much to be desired .
# Hyp | we has a thought of gold _EOS
# --------------------------------------------------
# precision | 0.0000
# recall | 0.0000
# --------------------------------------------------
# Src | その 装置 が 作動 し て い る 間 は 暖房 を 止め る こと は でき な い 。
# Ref | you can &apos;t turn the heat off as long as the system is operating .
# Hyp | the _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.1538
# recall | 0.1333
# --------------------------------------------------
# Src | ピクニック は 雨 の ため に 中止 に な っ た 。
# Ref | the picnic was called off because of rain .
# Hyp | a picnic because call rain rain rain rain rain rain rain _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3333
# --------------------------------------------------
# Src | 彼 は 週末 に よく 家 を 空け る 。
# Ref | he often stays away from home on the weekend .
# Hyp | he often across house on house . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.4000
# --------------------------------------------------
# Src | その シェパード は 、 びっこ を ひ き ながら 道 を 歩 い て い た 。
# Ref | the german shepherd was limping down the street .
# Hyp | the _UNK was easily the the the the . . _EOS
# --------------------------------------------------
# precision | 0.3636
# recall | 0.4444
# --------------------------------------------------
# Src | ボブ は 読 み きれ な い ほど たくさん の 本 を 持 っ て い る 。
# Ref | bob has too many books to read .
# Hyp | bob is a lot of a read . . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3750
# --------------------------------------------------
# Src | 板 に くぎ を 打ち込 ん だ 。
# Ref | he hammered nails into the plank .
# Hyp | i _UNK into _UNK into the . . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.4286
# --------------------------------------------------
# Src | 宿題 は もう 終わ っ た の で す か 。
# Ref | have you finished your homework already ?
# Hyp | have you finished your homework ? _EOS
# --------------------------------------------------
# precision | 0.8571
# recall | 0.8571
# --------------------------------------------------
# Src | まず その 辺 で す 。
# Ref | that &apos;s about it .
# Hyp | the _UNK , the _UNK . _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.2000
# --------------------------------------------------
# Src | 夢 は 、 世界 一周 旅行 。
# Ref | my dream is to take a round @-@ the @-@ world trip .
# Hyp | in dream &apos;s , . . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.1538
# --------------------------------------------------
# Src | 今夜 は 家 に つれ て い っ て く れ 。
# Ref | please take me home tonight .
# Hyp | let &apos;s very very tonight . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.3333
# --------------------------------------------------
# Src | ２ 日間 ベッド に い な く て は な ら な かっ た 。
# Ref | i have had to stay in bed for two days .
# Hyp | i had &apos;t make days two two . . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.4545
# --------------------------------------------------
# Src | 消防 士 は あっ と い う 間 に 火 を 消 し た 。
# Ref | the firemen had the fire out in no time .
# Hyp | i _UNK the _UNK knife the _UNK the . . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3000
# --------------------------------------------------
# Src | あなた の 傘 を 借り て い い で す か 。
# Ref | can i borrow your umbrella ?
# Hyp | could you like your your your ? _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3333
# --------------------------------------------------
# Src | 明日 雨降り なら 私 は 家 に い ま す 。
# Ref | i will stay home if it rains tomorrow .
# Hyp | i &apos;m house house at . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2222
# --------------------------------------------------
# Src | 彼女 が 最後 に ゴール し た 人 で す 。
# Ref | she was the last to cross the finishing line .
# Hyp | she is finished people of . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2000
# --------------------------------------------------
# Src | 写真 ほど 鮮明 な もの は な い 。
# Ref | nothing is more vivid than a picture .
# Hyp | there is no so a . . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3750
# --------------------------------------------------
# Src | 減税 は しばしば 経済 を 刺激 する 重要 な 財政 政策 手段 と し て 使 わ れ る 。
# Ref | tax cuts are often used as a major fiscal tool to stimulate the economy .
# Hyp | _UNK often expect _UNK the _UNK the the of of . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2000
# --------------------------------------------------
# Src | 橋 が 圧力 で 落ち た 。
# Ref | the bridge crashed under the pressure .
# Hyp | the bridge was down down the . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5714
# --------------------------------------------------
# Src | 私 は その 事実 を 十分 よく 知 っ て い る 。
# Ref | i know the facts well enough .
# Hyp | i know the to the the the . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.5714
# --------------------------------------------------
# Src | 彼 の 後 を 継 ぐ だけ の 能力 の あ る 人物 を 見つけ る の は 容易 で は な い だ ろ う 。
# Ref | it won &apos;t be easy to find someone capable of taking his place .
# Hyp | he can not _UNK his to his was he was an . . _EOS
# --------------------------------------------------
# precision | 0.2143
# recall | 0.2143
# --------------------------------------------------
# Src | 私 は 一 番 列車 に 間に合 う よう に 急 い だ 。
# Ref | i hurried in order to catch the first train .
# Hyp | i &apos;m hurry to our for for in in in in in _EOS
# --------------------------------------------------
# precision | 0.2308
# recall | 0.3000
# --------------------------------------------------
# Src | 私 は もはや 彼 の なまけ を 我慢 出来 な い 。
# Ref | i cannot put up with his idleness any longer .
# Hyp | i do not do him him . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2000
# --------------------------------------------------
# Src | 彼女 は 叔母 に 似 て い る 。
# Ref | she resembles her aunt .
# Hyp | she always adapted aunt . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.6000
# --------------------------------------------------
# Src | 彼 は い い 給料 を もら っ て い る 。
# Ref | he earns a good salary .
# Hyp | he has given his salary . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.5000
# --------------------------------------------------
# Src | 歌 を 歌 っ て い る 少年 は 私 の 弟 で す 。
# Ref | the boy singing a song is my brother .
# Hyp | it is a brother in brother brother . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.4444
# --------------------------------------------------
# Src | 彼女 は ベッド の 上 に うつ伏せ に 倒れ て い た 。
# Ref | she was lying face down on the bed .
# Hyp | she was down the on on on on _EOS
# --------------------------------------------------
# precision | 0.5556
# recall | 0.5556
# --------------------------------------------------
# Src | 急 い で する 事 が あ る 。
# Ref | i have an urgent matter to attend to .
# Hyp | hurry have hurry in . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.2222
# --------------------------------------------------
# Src | 私 は 、 ストライキ の ため に 、 旅行 を 中止 し な けれ ば な ら な かっ た 。
# Ref | i had to cancel my trip on account of the strike .
# Hyp | i had to get travel for to . . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.3333
# --------------------------------------------------
# Src | だれ で も が み な 正直 と は 限 ら な い 。
# Ref | everyone is not honest .
# Hyp | everyone is amount not _UNK in in . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.8000
# --------------------------------------------------
# Src | もし 私 が 君 の 立場 なら 、 彼 を 手伝 っ て や る だ ろ う に 。
# Ref | if i were in your place , i would lend him a hand .
# Hyp | if you you sorry you you you you help help help help help help _EOS
# --------------------------------------------------
# precision | 0.0667
# recall | 0.0714
# --------------------------------------------------
# Src | 早起き の 習慣 を 養 う よう に し なさ い 。
# Ref | you should cultivate the habit of getting up early .
# Hyp | brush your to of . . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2000
# --------------------------------------------------
# Src | 君 に 会 っ た こと を 私 は 決して 忘れ ま せ ん 。
# Ref | i will never forget seeing you .
# Hyp | i &apos;m never forget you i seeing you . _EOS
# --------------------------------------------------
# precision | 0.6000
# recall | 0.8571
# --------------------------------------------------
# Src | カナダ へ 行 っ た こと が あ り ま す か 。
# Ref | have you ever been to canada ?
# Hyp | do i have a canada canada ? _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | バス の 前 の ほう は す い て い た 。
# Ref | the front of the bus was not crowded .
# Hyp | the _UNK was in the the the bus . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5556
# --------------------------------------------------
# Src | 彼 は 出かけ た 先々 で 歓迎 さ れ た 。
# Ref | he was welcomed wherever he went .
# Hyp | he was been by by by . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | 彼 は 自分 が 何 を 話 し て い る か を 時々 忘れ て しま う 。
# Ref | he sometimes forgets what he was talking about .
# Hyp | he is forget to to you good talk . . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.2222
# --------------------------------------------------
# Src | 彼女 は その 仕事 を する 気分 で は な い 。
# Ref | she is in no humor for task .
# Hyp | she is not the the the the _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2500
# --------------------------------------------------
# Src | 私 は 野球 が 好き だ 。
# Ref | i like baseball .
# Hyp | i like play . _EOS
# --------------------------------------------------
# precision | 0.6000
# recall | 0.7500
# --------------------------------------------------
# Src | その 名 の 人 は 学籍 簿 に 載 っ て ま せ ん 。
# Ref | no person by that name is listed in the register of the school .
# Hyp | a _UNK name _UNK _UNK _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.1429
# --------------------------------------------------
# Src | 収穫 が もっと 悪 く な れ ば 、 飢饉 が 起こ る か も 知れ な い 。
# Ref | if the harvest gets any worse , there could be a famine .
# Hyp | we can not ensure , in in . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.1538
# --------------------------------------------------
# Src | 父 は 私 が 彼 に 対 し て 失礼 な 言動 を と っ た とき 、 怒り で 顔 が 真っ赤 に な っ た 。
# Ref | father went red with anger when i behaved rudely towards him .
# Hyp | my father was a with and and and but but . . _EOS
# --------------------------------------------------
# precision | 0.2308
# recall | 0.2500
# --------------------------------------------------
# Src | 彼 は 山 の 頂上 に 立 っ て い ま し た 。
# Ref | he was standing at the top of the mountain .
# Hyp | he father herself of of of mountain . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.4000
# --------------------------------------------------
# Src | 私 たち みんな 自転 車 に 乗 る の が 好き で す 。
# Ref | we all like cycling .
# Hyp | we like a ride a a a . . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.6000
# --------------------------------------------------
# Src | 赤ん坊 は よく 転 ぶ 。
# Ref | babies often fall down .
# Hyp | the baby often frightened . . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.4000
# --------------------------------------------------
# Src | その 質問 は 難し すぎ て 答え られ な かっ た 。
# Ref | the question was too difficult to answer .
# Hyp | the answer was too me by me . _EOS
# --------------------------------------------------
# precision | 0.5556
# recall | 0.6250
# --------------------------------------------------
# Src | 彼女 は 教師 の よう に 見え る 。
# Ref | she looks like a teacher .
# Hyp | she seems to a for teacher teacher for . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.6667
# --------------------------------------------------
# Src | ジョーダン さん は 「 授業 に 出 て い な かっ た の で す か 」 と たずね た 。
# Ref | &quot; weren &apos;t you there ? &quot; asked mr jordan .
# Hyp | &quot; did you to , &quot; &quot; &quot; &quot; &quot; ? class _EOS
# --------------------------------------------------
# precision | 0.3077
# recall | 0.3636
# --------------------------------------------------
# Src | 「 ほか に 何 か 要 り ま す か 」 「 それ だけ で 結構 で す 」
# Ref | &quot; anything else ? &quot; &quot; no , that &apos;s all . &quot;
# Hyp | &quot; is i , , , &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot;
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3846
# --------------------------------------------------
# Src | 気 苦労 が 彼 の 体 に 響 い た 。
# Ref | worry affected his health .
# Hyp | i felt him home home home . _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.2000
# --------------------------------------------------
# Src | 彼 は それ を 詳し く 説明 し だ し た 。
# Ref | he explained it at length .
# Hyp | he _UNK for for for for . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3333
# --------------------------------------------------
# Src | 「 元気 を 出 し なさ い 」 と 彼女 は 私 に 言 い ま し た 。
# Ref | &quot; cheer up , &quot; she said to me .
# Hyp | i talk get out of me me &quot; . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3000
# --------------------------------------------------
# Src | 本当 を 言 う と 、 コンピューター に は 詳し く な い の で す 。
# Ref | i &apos;m not really familiar with computers .
# Hyp | i really not to to to to . . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.5000
# --------------------------------------------------
# Src | ワイン を もっと 冷や し た い 。
# Ref | i want to chill the wine more .
# Hyp | we yourself to more deal . . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3750
# --------------------------------------------------
# Src | 彼女 は 機嫌 が 悪 い と い う の も 、 いつ も 地下 鉄 に 乗 り 遅れ 仕事 場 まで 歩 く 羽目 に な っ た から だ 。
# Ref | she is in a temper , because she missed her usual train in the subway and had to walk to work .
# Hyp | she was she the _UNK the the the the the . . . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.1818
# --------------------------------------------------
# Src | 夕方 から 雨 だ って い っ て い た よ 。
# Ref | it said rain from this evening .
# Hyp | it &apos;ve got it . . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | あす の 朝 まで に は 一面 の 銀 世界 に な っ て い る だ ろ う 。
# Ref | by tomorrow morning all the world will have been covered with snow .
# Hyp | a will _UNK the the the the morning the . _EOS
# --------------------------------------------------
# precision | 0.3636
# recall | 0.3077
# --------------------------------------------------
# Src | 知 っ て い れ ば 教え て あげ た ん だ けど 。
# Ref | had i known it , i would have told you .
# Hyp | i &apos;ve had about what i had . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.3636
# --------------------------------------------------
# Src | 無知 は 幸福 。
# Ref | ignorance is bliss .
# Hyp | a &apos;s happy . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2500
# --------------------------------------------------
# Src | せっかく 弁護 士 の 資格 が あ る の に もったい な い 。
# Ref | what a waste of your lawyer qualifications !
# Hyp | we can have a _UNK _UNK _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.1250
# --------------------------------------------------
# Src | 少な い 収入 を でき る 限り いか し た い 。
# Ref | make the best of your small income .
# Hyp | i want you far far as as to @-@ . . . . . . _EOS
# --------------------------------------------------
# precision | 0.0625
# recall | 0.1250
# --------------------------------------------------
# Src | いつ か あなた を 訪問 し て も い い で す か 。
# Ref | may i call on you some day ?
# Hyp | would you ever no do ? ? _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2500
# --------------------------------------------------
# Src | 私 は ここ に とどま る べ き か ロンドン へ 行 く べ き か 分か ら な かっ た 。
# Ref | i didn &apos;t know whether to stay here or go to london .
# Hyp | i didn &apos;t go to to to here here . _EOS
# --------------------------------------------------
# precision | 0.7273
# recall | 0.6154
# --------------------------------------------------
# Src | ダン は よく お 母 さん に しか ら れ る 。
# Ref | dan is often scolded by his mother .
# Hyp | _UNK often turn a a for back . . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2500
# --------------------------------------------------
# Src | ジョージ は とても 話 好き だ 。
# Ref | george is quite talkative .
# Hyp | it is very lot of . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.4000
# --------------------------------------------------
# Src | システム が 作動 し な い 場合 が あ る 。
# Ref | there are cases where the system doesn &apos;t go .
# Hyp | a _UNK a _UNK _UNK _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1000
# --------------------------------------------------
# Src | 彼女 は 毎週 １ 回 映画 を 見 に 行 く 。
# Ref | she goes to the movies once a week .
# Hyp | she is the of of the movies the . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.4444
# --------------------------------------------------
# Src | 彼 は とって も やさし い よ 。
# Ref | he is fine and gentle .
# Hyp | he &apos;s an easy . . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.3333
# --------------------------------------------------
# Src | 私 は ほとんど １８０ センチ で す 。
# Ref | i am almost 180 centimeters tall .
# Hyp | i temperature little in . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.2857
# --------------------------------------------------
# Src | 彼 は 母親 に 似 て い る 。
# Ref | he resembles his mother .
# Hyp | he lives takes to . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.4000
# --------------------------------------------------
# Src | 東京 は だんぜん 日本 で 一番 大き い 都市 で す 。
# Ref | tokyo is by far the largest city in japan .
# Hyp | it is my meat the the in in . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.4000
# --------------------------------------------------
# Src | 出世 し た い の なら 、 努力 を おそれ て は な ら な い 。
# Ref | if you wish to get on in the world , you must not shrink from effort .
# Hyp | no your , give give give give give possible . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.1176
# --------------------------------------------------
# Src | 「 まだ 浅 い ね 。 足 とど く 」 「 結構 遠浅 だ な 。 よ つば も まだ 足 つ く だ ろ 」
# Ref | &quot; it &apos;s still shallow , eh . my feet still touch the bottom . &quot; &quot; it &apos;s quite a shallow beach . yotsuba , you can still touch the bottom can &apos;t you ? &quot;
# Hyp | &quot; don &apos;t &apos;t , , &apos;t , &apos;t it it it it it it it . _EOS
# --------------------------------------------------
# precision | 0.3889
# recall | 0.1892
# --------------------------------------------------
# Src | 私 の お じい ちゃん は 私 が 大学 に 行 く こと を 望 ん で い る 。
# Ref | my grandfather hopes that i will enter college .
# Hyp | my my i going to to go go . . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3333
# --------------------------------------------------
# Src | ラスベガス が い る と 時間 が 経 つ の を 忘れ る 。
# Ref | it &apos;s easy to lose track of time when you are in las vegas .
# Hyp | _UNK will _UNK it it will will he . . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.1333
# --------------------------------------------------
# Src | 彼 は 非常 な 剣幕 で 私 を にらみ付け た 。
# Ref | he glared at me fiercely .
# Hyp | he _UNK me on _UNK . . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.5000
# --------------------------------------------------
# Src | 間 の 垣根 が 恋 を いっそう 燃え立 た せ る 。
# Ref | a fence between makes love more keen .
# Hyp | we _UNK off off off the middle . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1250
# --------------------------------------------------
# Src | キャロライン は すべて の お 金 を 洋服 に 使 う ほど 愚か で は な い 。
# Ref | caroline knows better than to spend all her money on clothes .
# Hyp | i &apos;m not take all all all . . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.1667
# --------------------------------------------------
# Src | 彼 は 駐日 アメリカ 大使 に 命 じ られ た ばかり で す 。
# Ref | he has just been appointed the u.s. ambassador to japan .
# Hyp | he is been in in _UNK . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.2727
# --------------------------------------------------
# Src | 彼女 なら 当然 選 び そう な 人 と 彼女 は 結婚 し た 。
# Ref | she married to the kind of man you would expect her to pick .
# Hyp | she _UNK that that that she she she . . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.1429
# --------------------------------------------------
# Src | 昨日 通り で 友人 に 会 っ た 。
# Ref | i met my friend on the street .
# Hyp | i met seeing yesterday yesterday yesterday _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2500
# --------------------------------------------------
# Src | お 酒 を 飲 む と 影響 が 出 る もの だ 。
# Ref | liquor will have an effect on a person .
# Hyp | when will get get when drinking drinking . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2222
# --------------------------------------------------
# Src | 君 を 信頼 し て い る 。
# Ref | i believe in you .
# Hyp | you &apos;re looking looking you . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.4000
# --------------------------------------------------
# Src | 我々 の 列車 は 時速 ２００ キロ で 走 っ た 。
# Ref | our train went at 200 kilometers an hour .
# Hyp | we _UNK run the _UNK the the . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1111
# --------------------------------------------------
# Src | 私 たち は 泣 い て い る の 。
# Ref | we are crying .
# Hyp | we are fine . _EOS
# --------------------------------------------------
# precision | 0.6000
# recall | 0.7500
# --------------------------------------------------
# Src | 彼女 は 息 を 飲 ん だ 。
# Ref | she caught her breath .
# Hyp | she drank she she . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.4000
# --------------------------------------------------
# Src | 君 たち は 大人 に な る まで タバコ を 吸 っ て は いけ な い 。
# Ref | you must not smoke till you grow up .
# Hyp | you are not at at so so so . . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3333
# --------------------------------------------------
# Src | 彼 は たばこ を 一 日 一 本 に 減ら し て い っ た 。
# Ref | he tapered off to one cigarette a day .
# Hyp | he _UNK on day on day day . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3333
# --------------------------------------------------
# Src | 貴殿 の 娘 さん は 麻薬 漬け で す 。
# Ref | your daughter &apos;s on drugs .
# Hyp | my _UNK _UNK _UNK _UNK _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1667
# --------------------------------------------------
# Src | 彼女 を その 任務 に 就け よう 。
# Ref | let &apos;s put her in charge of that .
# Hyp | let &apos;s _UNK the the the her her . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.4444
# --------------------------------------------------
# Src | ある 旅行 会社 が 我々 の 旅行 の 手配 を 全部 し て くれ た 。
# Ref | a travel agent arranged everything for our trip .
# Hyp | i _UNK the all the us . . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1111
# --------------------------------------------------
# Src | 彼女 が 息子 を 自慢 する の も もっとも だ 。
# Ref | she may well be proud of her son .
# Hyp | she proud proud proud proud son son . . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.4444
# --------------------------------------------------
# Src | 痛み が 右脚 に 走 り ま す 。
# Ref | the pain shoots into my right leg .
# Hyp | i will run run _UNK . _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.1250
# --------------------------------------------------
# Src | 参加 者 の リスト は 次 の とおり で す 。
# ...
# --------------------------------------------------
# Src | 少し 待 っ て くれ た ら 、 ジェーン を 電話 に 出 さ せ ま す 。
# Ref | if you hold on a moment , i will get jane on the phone .
# Hyp | i &apos;m just at phone just phone phone phone . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2000
# --------------------------------------------------
# Src | 彼女 と は ときおり 美容 院 で 会 い ま す 。
# Ref | i meet her on occasion at a beauty shop .
# Hyp | she is her with _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2000
# --------------------------------------------------
# Src | しかし 、 主人 公 は 自ら の 誤り に 気づ い て い る 。
# Ref | however the protagonist is aware of his own mistakes .
# Hyp | but _UNK are _UNK are are are are are . _EOS
# --------------------------------------------------
# precision | 0.0909
# recall | 0.1000
# --------------------------------------------------
# Src | 私 は 彼 の 態度 に 我慢 でき な い 。
# Ref | i cannot abide his manner .
# Hyp | i can &apos;t without his his . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.5000
# --------------------------------------------------
# Src | 彼 は 何事 も 程々 と い う 事 を 知 ら ず 、 いつ も 極端 に 走 っ て しま う 。
# Ref | he is the kind of man who cannot do anything in moderation , but always goes to extremes .
# Hyp | i &apos;m always _UNK _UNK _UNK _UNK _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.1053
# --------------------------------------------------
# Src | 道路 を 横断 する とき に は 注意 し なさ い 。
# Ref | you must be careful in crossing the road .
# Hyp | boil on careful careful the the the . . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3333
# --------------------------------------------------
# Src | 自分 の こと だけ 気 に かけ ろ ！
# Ref | mind your own business !
# Hyp | what own _UNK own own own _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.2000
# --------------------------------------------------
# Src | 友人 は マイ カー を 欲し が っ て い る 。
# Ref | my friend wants a car of his own .
# Hyp | a have been to _UNK . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2222
# --------------------------------------------------
# Src | 彼女 は 私 の ひじ を 引っ張 っ た 。
# Ref | she gave a pluck at my elbow .
# Hyp | she bought the my my . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.3750
# --------------------------------------------------
# Src | 何 が 起こ ろ う と も 、 私 は あなた の 味方 を する 。
# Ref | i will stand by you whatever happens .
# Hyp | prepared am am am am am am am am _EOS
# --------------------------------------------------
# precision | 0.0000
# recall | 0.0000
# --------------------------------------------------
# Src | コーヒー を 飲 み ま す か 。
# Ref | will you have some coffee ?
# Hyp | do you coffee coffee coffee coffee ? ? _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.5000
# --------------------------------------------------
# Src | 気持ち を 御 察し し ま す 。
# Ref | i understand how you feel .
# Hyp | i will my my my . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.3333
# --------------------------------------------------
# Src | にわか 雨 に な る らし い で す よ 。
# Ref | they say we &apos;re going to get some showers .
# Hyp | it &apos;s say &apos;re a &apos;re wet . . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3000
# --------------------------------------------------
# Src | 何事 も 最初 が 肝心 だ よ な 。
# Ref | whatever you &apos;re doing , starting off on the right foot is essential .
# Hyp | is best _UNK _UNK _UNK best best first _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.0714
# --------------------------------------------------
# Src | その 語 は 誤用 さ れ やす い 。
# Ref | the word lends itself to misuse by beginners .
# Hyp | the shouldn is is to _UNK . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3333
# --------------------------------------------------
# Src | 彼 ら は 設計 図 どおり に 船 を 作 っ た 。
# Ref | they built the ship in accordance with the plans .
# Hyp | they made a sail on on . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2000
# --------------------------------------------------
# Src | ほんの ２、３ 日 前 に 彼女 に 会 っ た 。
# Ref | i saw her just the other day .
# Hyp | just her long at long long . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3750
# --------------------------------------------------
# Src | それ は どの ゲート で す か 。
# Ref | which gate is that ?
# Hyp | which do it it it ? _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.4000
# --------------------------------------------------
# Src | 私 は 何 と し て も 酒 を 止め る つもり で す 。
# Ref | i will give up drinking at any cost .
# Hyp | i will like _UNK writing writing writing . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3333
# --------------------------------------------------
# Src | 夜 の ツアー は あ り ま す か 。
# Ref | do you offer any night tours ?
# Hyp | certainly on _UNK _UNK ? _EOS
# --------------------------------------------------
# precision | 0.1667
# recall | 0.1429
# --------------------------------------------------
# Src | もっと 分別 が あ っ て も い い 年頃 だ よ 。
# Ref | you &apos;re old enough to know better .
# Hyp | sorry , more more more , . _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.1250
# --------------------------------------------------
# Src | この 停留 所 から ５ 番 目 の バス に 乗り なさ い 。
# Ref | take a no . 5 bus at this bus stop .
# Hyp | stop this the in the _UNK in . . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.3636
# --------------------------------------------------
# Src | 彼 に は お 金 が 足り な い よう だっ た 。
# Ref | it seemed that he was short of money .
# Hyp | he didn nothing nothing money . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.3333
# --------------------------------------------------
# Src | 彼 は 彼女 を 援助 し て や る 必要 が あ り ま す か 。
# Ref | does he need to help her ?
# Hyp | is i help your painting on ? _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | 軽 い 風邪 で す 。
# Ref | it &apos;s only a slight cold .
# Hyp | i is just a a cold _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2857
# --------------------------------------------------
# Src | サッカー チーム 全体 が 優勝 し て 浮き浮き し て た 。
# Ref | the whole soccer team was on cloud nine after winning the championship .
# Hyp | the soccer brought the the the soccer . . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.3077
# --------------------------------------------------
# Src | この 町 は 気 に 入 り ま し た か 。
# Ref | how do you like this town ?
# Hyp | have this rude care this ? _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2857
# --------------------------------------------------
# Src | 冬 は 過ぎ去 っ た 。
# Ref | winter is gone .
# Hyp | we &apos;ve been in in in . . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.2500
# --------------------------------------------------
# Src | 彼 の 助け 無し に は 、 や っ て いけ な い 。
# Ref | i cannot manage without his support .
# Hyp | don &apos;t do to his help help help . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2857
# --------------------------------------------------
# Src | この ホール は 最大 で １０００ 人 収容 でき る 。
# Ref | this hall holds a maximum of 1,000 people .
# Hyp | this this is in in in in . . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2222
# --------------------------------------------------
# Src | 天気 予報 は どう で し た か 。
# Ref | what was the weather report ?
# Hyp | why were _UNK _UNK ? ? ? _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.1667
# --------------------------------------------------
# Src | 再三 彼 ら を 招待 し た が 決して こ な かっ た 。
# Ref | time after time i &apos;ve invited them to come over and visit us but time and time again they &apos;ve never come .
# Hyp | no _UNK _UNK on on on _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.0435
# --------------------------------------------------
# Src | 誰 も が 彼 の 技術 を 認め た 。
# Ref | everyone recognized his skill .
# Hyp | i _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2000
# --------------------------------------------------
# Src | 貴方 は 、 明日 学校 に 行 く だ ろ う 。
# Ref | you &apos;ll go to school tomorrow .
# Hyp | this would go to go school school school school school _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.4286
# --------------------------------------------------
# Src | この データ は その 議論 に と っ て 重要 だ 。
# Ref | this data is immaterial to the argument .
# Hyp | this data has to the the the the the _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.5000
# --------------------------------------------------
# Src | 彼女 と は よく 会 い ま す か 。
# Ref | do you see her often ?
# Hyp | do you well her her ? _EOS
# --------------------------------------------------
# precision | 0.5714
# recall | 0.6667
# --------------------------------------------------
# Src | 彼 ら は 容易 な ら ぬ 事態 に 直面 し て い る 。
# Ref | they are faced with a serious situation .
# Hyp | they are a at on on on . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.5000
# --------------------------------------------------
# Src | 多く の 時間 が 無駄 に な っ た 。
# Ref | much time was wasted .
# Hyp | many _UNK many lot for for . _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.2000
# --------------------------------------------------
# Src | 僕 の もの は 全て 君 の 物 だ 。
# Ref | whatever i have is yours .
# Hyp | our our tells are your your . _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.1667
# --------------------------------------------------
# Src | ステーキ は 中位 で 焼 い て くださ い 。
# Ref | i like my steak medium .
# Hyp | i like steak steak medium . _EOS
# --------------------------------------------------
# precision | 0.7143
# recall | 0.8333
# sentences matching filter = 500
